# %%
str="Prathamesh"

# %%
print(str)
# Out:
# Prathamesh

# %%
first_name='prathamesh'
last_name='dabhole'

# %%
first_name+last_name
# Out:
# 'prathameshdabhole'

# %%
first_name.capitalize
# Out:
# <function str.capitalize()>

# %%
first_name.capitalize()
# Out:
# 'Prathamesh'

# %%
last_name.capitalize()
# Out:
# 'Dabhole'

# %%
first_name.count(a)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 first_name.count(a)
#
# NameError: name 'a' is not defined

# %%
first_name.count('a')
# Out:
# 2

# %%
first_name.count('h')
# Out:
# 2

# %%
line='a'*10

# %%
print(line)
# Out:
# aaaaaaaaaa

# %%
word='Python'
word[0]
# Out:
# 'P'

# %%
word[-1]
# Out:
# 'n'

# %%
print(word[0:2]) #from index 0 up to, not including, 2
# Out:
# Py

# %%
print(word[2:]) #from index 2 to the end
# Out:
# thon

# %%
print(word[:4]) #from start up to index 4
# Out:
# Pyth

# %%
print(len(word))
# Out:
# 6

# %%
text = "hello WORLD"

# %%
text.capitalize() #Capitalizes only the first letter
# Out:
# 'Hello world'

# %%
text.title() #Converts to "title case" (first letter of each word capitalized).
# Out:
# 'Hello World'

# %%
text.upper()
# Out:
# 'HELLO WORLD'

# %%
text.lower()
# Out:
# 'hello world'

# %%
data = "  apple,banana,cherry  "

# %%
print(data)
# Out:
#   apple,banana,cherry

# %%
print(data.strip()) #Removes whitespace (spaces, tabs, newlines) from the beginning and end.
# Out:
# apple,banana,cherry

# %%
items = "apple,banana,cherry".split(",") #Splits the string into a list of substrings, using the separator. If no separator is given, it splits by whitespace.
print(items)
# Out:
# ['apple', 'banana', 'cherry']

# %%
print("-".join(items)) #Joins elements of a list into a single string
# Out:
# apple-banana-cherry

# %%
sentence = "I like cats and cats are great."
print(sentence.find("cats")) #Returns the starting index of the first occurrence of the substring or -1 if not found.
# Out:
# 7

# %%
print(sentence.replace("cats", "dogs"))  #returns a new string with all occurrences of old replaced by new.
# Out:
# I like dogs and dogs are great.

# %%
word="Big Data"
word.isalpha()
word.isalnum()
word.isdigit()
word.istitle()
# Out:
# True

# %%
list_a = [1, 2, 3]
list_b = [4, 5, 6]

# %%
list_a+list_b
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
numbers = [3, 1, 4, 1, 5]

# %%
# Using sorted() - Original stays the same
sorted_numbers = sorted(numbers)
sorted_numbers
# Out:
# [1, 1, 3, 4, 5]

# %%
print(numbers)
# Out:
# [1, 1, 3, 4, 5]

# %%
numbers.sort()
print(numbers)
# Out:
# [1, 1, 3, 4, 5]

# %%
letters = ['a', 'b', 'c']
letters.reverse()
print(letters)
# Out:
# ['c', 'b', 'a']

# %%
letters.pop()
# Out:
# 'a'

# %%
letters.append('c')

# %%
letters
# Out:
# ['c', 'b', 'c']

# %%
letters.index
# Out:
# <function list.index(value, start=0, stop=9223372036854775807, /)>

# %%
letters.index()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[68], line 1
# ----> 1 letters.index()
#
# TypeError: index expected at least 1 argument, got 0

# %%
letters.index('c') #Returns the index of the first item
# Out:
# 0

# %%
letters.insert(3,'d')

# %%
letters
# Out:
# ['c', 'b', 'c', 'd']

# %%
set_small = {1, 2}
set_large = {1, 2, 3, 4}

# %%
set_small.union(set_large)
# Out:
# {1, 2, 3, 4}

# %%
set_small.intersection(set_large)
# Out:
# {1, 2}

# %%
set_small.difference(set_large)
# Out:
# set()

# %%
set_large.add(5,6,7,8,9)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 set_large.add(5,6,7,8,9)
#
# TypeError: set.add() takes exactly one argument (5 given)

# %%
set_large(7)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 set_large(7)
#
# TypeError: 'set' object is not callable

# %%
set_large.add(7)

# %%
set_small.difference(set_large)
# Out:
# set()

# %%
set_large
# Out:
# {1, 2, 3, 4, 7}

# %%
set_large.difference(set_small)
# Out:
# {3, 4, 7}

# %%
set_small.discard #If Element Not Found	No error is raised; the set remains unchanged.
# Out:
# <function set.discard>

# %%
set_small
# Out:
# {1, 2}

# %%
set_small.remove() #If Element Not Found;Raises a KeyError.
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 set_small.remove()
#
# TypeError: set.remove() takes exactly one argument (0 given)

# %%
set_small.remove(2)

# %%
set_small
# Out:
# {2, 3, 4, 5, 6}

# %%
set_small.add(2)

# %%
new_elements = [3, 4,5,6]

# %%
set_small.update(new_elements) #The .update() method. It takes any iterable (such as a list, tuple, or another set) 
#as an argument and adds all its unique elements to the existing set

# %%
set_small.pop()
# Out:
# 1

# %%
set_small.symmetric_difference(set_large) #Return the symmetric difference of two sets as a new set.
# Out:
# {1, 5, 6, 7}

# %%
copy_set={}

# %%
set_small.copy(copy_set)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 set_small.copy(copy_set)
#
# TypeError: set.copy() takes no arguments (1 given)

# %%
copy_set.copy(set_small)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 copy_set.copy(set_small)
#
# TypeError: dict.copy() takes no arguments (1 given)

# %%
copy_set=set_small.copy()

# %%
copy_set
# Out:
# {2, 3, 4, 5, 6}

# %%
my_tuple = ('a', 'b', 'c', 'd')

# %%
print(my_tuple[1])
# Out:
# b

# %%
print(my_tuple[-1])
# Out:
# d

# %%
print(my_tuple[1:4])
# Out:
# ('b', 'c', 'd')

# %%
print(my_tuple[:3])
# Out:
# ('a', 'b', 'c')

# %%
print('d' in my_tuple)
# Out:
# True

# %%
print(2 in my_tuple)
# Out:
# False

# %%
car = {
    "brand": "Ford",
    "model": "Mustang",
    "year": 1964,
    "colors": ["red", "white", "blue"] # Value can be a mutable type like a list
}

# %%
print(car["model"])
# Out:
# Mustang

# %%
dict(car[''])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[42], line 1
# ----> 1 dict(car[''])
#
# KeyError: ''

# %%
dict.get()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[43], line 1
# ----> 1 dict.get()
#
# TypeError: unbound method dict.get() needs an argument

# %%
dict.get('')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[44], line 1
# ----> 1 dict.get('')
#
# TypeError: descriptor 'get' for 'dict' objects doesn't apply to a 'str' object

# %%
dict.get('model')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[45], line 1
# ----> 1 dict.get('model')
#
# TypeError: descriptor 'get' for 'dict' objects doesn't apply to a 'str' object

# %%
car.get('model')
# Out:
# 'Mustang'

# %%
car.get('')

# %%
car.get("owner", "Not Listed")
# Out:
# 'Not Listed'

# %%
car["engine"] = "V8"

# %%
car["year"] = 1965

# %%
car
# Out:
# {'brand': 'Ford',
#  'model': 'Mustang',
#  'year': 1965,
#  'colors': ['red', 'white', 'blue']}

# %%
car.pop()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[52], line 1
# ----> 1 car.pop()
#
# TypeError: pop expected at least 1 argument, got 0

# %%
car.pop('engine') #.pop() is to remove and return the value for a specific key you provide.
# Out:
# 'V8'

# %%
car.popitem() #The .popitem() method is used to remove and return an arbitrary item from the dictionary as a tuple
# Out:
# ('engine', 'V8')

# %%
car.keys
# Out:
# <function dict.keys>

# %%
car.key()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[60], line 1
# ----> 1 car.key()
#
# AttributeError: 'dict' object has no attribute 'key'
